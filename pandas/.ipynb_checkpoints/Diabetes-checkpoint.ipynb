# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### IMPORTING DATA-SET

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 250            9      106             52              0        0  31.2
# 86            13      106             72             54        0  36.6
# 414            0      138             60             35      167  34.6
# 74             1       79             75             30        0  32.0
# 693            7      129             68             49      125  38.5
# 266            0      138              0              0        0  36.3
# 339            7      178             84              0        0  39.9
# 614           11      138             74             26      144  36.1
# 300            0      167              0              0        0  32.3
# 38             2       90             68             42        0  38.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 250                     0.380   42        0
# 86                      0.178   45        0
# 414                     0.534   21        1
# 74                      0.396   22        0
# 693                     0.439   43        1
# 266                     0.933   25        1
# 339                     0.331   41        1
# 614                     0.557   50        1
# 300                     0.839   30        1
# 38                      0.503   27        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # DESCRIPTION OF DATA-SET

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# # Data Cleaning

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # Replacing null value with its Mean value

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# # Data Visualisation

# %%
sns.countplot(x = 'Outcome',data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %% [markdown]
# ### Histogram

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(20,20));

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(data=df,hue='Outcome')
plt.show()

# %% [markdown]
# ### Heat Map

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
target_name = 'Outcome'
X= df.drop(target_name, axis= 1)
y= df[target_name]
X.head()
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)
SSX=scaler.transform(X)

# %% [markdown]
# # Train and Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(SSX,y,test_size=0.2,random_state=7)

# %%
X_train.shape,y_train.shape
# Out:
# ((614, 8), (614,))

# %%
X_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# # Applying Classification Algorithm

# %% [markdown]
# #### 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear',multi_class='ovr')
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %% [markdown]
# #### 2. KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### 3. SVC

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# #### 4. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### 5. Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# #### 6. RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier( criterion = 'entropy')
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
X_test.shape
# Out:
# (154, 8)

# %%
lr_pred = lr.predict(X_test)
pred_knn = knn.predict(X_test)
pred_svc = svc.predict(X_test)
pred_nb = nb.predict(X_test)
pred_dt = dt.predict(X_test)
pred_rf = rf.predict(X_test)

# %%
lr_pred.shape
# Out:
# (154,)

# %%
pred_knn.shape
# Out:
# (154,)

# %%
pred_svc.shape
# Out:
# (154,)

# %%
pred_nb.shape
# Out:
# (154,)

# %%
pred_dt.shape
# Out:
# (154,)

# %%
pred_rf.shape
# Out:
# (154,)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# # Predicting the Accuracy of Test and Train data-set

# %% [markdown]
# #### 1. Logistic Regression

# %%
from sklearn.metrics import accuracy_score
print("train accuracy of Logistic Regression", lr.score(X_train, y_train)*100)
print("Accuracy(test) Score of Logistic Regression ", lr.score(X_test, y_test)*100)
print("Accuracy(test) Score of Logistic Regression ", accuracy_score(y_test, lr_pred)*100)
# Out:
# train accuracy of Logistic Regression 77.36156351791531
# Accuracy(test) Score of Logistic Regression  77.27272727272727
# Accuracy(test) Score of Logistic Regression  77.27272727272727

# %% [markdown]
# #### 1. KNN

# %%
print("train accuracy of KNN", knn.score(X_train, y_train)*100)
print("Accuracy(test) Score of KNN ", knn.score(X_test, y_test)*100)
print("Accuracy(test) Score of KNN ", accuracy_score(y_test, pred_knn)*100)
# Out:
# train accuracy of KNN 81.10749185667753
# Accuracy(test) Score of KNN  74.67532467532467
# Accuracy(test) Score of KNN  74.67532467532467

# %% [markdown]
# #### 3. Naive Bayes

# %%
print("train accuracy of Naiv Bayes", nb.score(X_train, y_train)*100)
print("Accuracy(test) Score of Naiv Bays ", nb.score(X_test, y_test)*100)
print("Accuracy(test) Score of Naiv Bays ", accuracy_score(y_test, pred_nb)*100)
# Out:
# train accuracy of Naiv Bayes 74.2671009771987
# Accuracy(test) Score of Naiv Bays  74.02597402597402
# Accuracy(test) Score of Naiv Bays  74.02597402597402

# %% [markdown]
# #### 4. SVC

# %%
print("train accuracy of SVC", svc.score(X_train, y_train)*100)
print("Accuracy(test) Score of SVC ", svc.score(X_test, y_test)*100)
print("Accuracy(test) Score of SVC ", accuracy_score(y_test, pred_svc)*100)
# Out:
# train accuracy of SVC 81.92182410423453
# Accuracy(test) Score of SVC  83.11688311688312
# Accuracy(test) Score of SVC  83.11688311688312

# %% [markdown]
# #### 5. Decision Tree

# %%
print("train accuracy of Decision Tree", dt.score(X_train, y_train)*100)
print("Accuracy(test) Score of Decision Tree ", dt.score(X_test, y_test)*100)
print("Accuracy(test) Score of Decision Tree ", accuracy_score(y_test, pred_dt)*100)
# Out:
# train accuracy of Decision Tree 100.0
# Accuracy(test) Score of Decision Tree  81.16883116883116
# Accuracy(test) Score of Decision Tree  81.16883116883116

# %% [markdown]
# #### 6. Random Forest

# %%
print("train accuracy of Random Forest", rf.score(X_train, y_train)*100)
print("Accuracy(test) Score of Random Forest ", rf.score(X_test, y_test)*100)
print("Accuracy(test) Score of Random Forest ", accuracy_score(y_test, pred_rf)*100)
# Out:
# train accuracy of Random Forest 100.0
# Accuracy(test) Score of Random Forest  77.92207792207793
# Accuracy(test) Score of Random Forest  77.92207792207793

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix
cm= confusion_matrix(y_test, lr_pred)
cm
# Out:
# array([[86, 11],
#        [24, 33]])

# %%
sns.heatmap(confusion_matrix(y_test, lr_pred),annot= True, fmt="d" )
# Out:
# <Axes: >

# %%
print('classification report of loestic regression: \n', classification_report(y_test, lr_pred, digits=4))
# Out:
# classification report of loestic regression:
#                precision    recall  f1-score   support
#
#            0     0.7818    0.8866    0.8309        97
#            1     0.7500    0.5789    0.6535        57
#
#     accuracy                         0.7727       154
#    macro avg     0.7659    0.7328    0.7422       154
# weighted avg     0.7700    0.7727    0.7652       154

# %%
TN= cm[0,0]
FP= cm[0,1]
FN= cm[1,0]
TP= cm[1,1]

# %%
TN,FP,FN,TP
# Out:
# (86, 11, 24, 33)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm= confusion_matrix(y_test, lr_pred)
print('TN-True negative{}'.format (cm[0,0]))
print('FP-False positive{}'.format (cm[0,1]))
print('TP-True negative{}'.format (cm[1,1]))
print('FN-False positive{}'.format (cm[1,0]))
print('Accuracy rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Miscalssification rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN-True negative86
# FP-False positive11
# TP-True negative33
# FN-False positive24
# Accuracy rate: 77.27272727272727
# Miscalssification rate: 22.727272727272727

# %%
import matplotlib.pyplot as plt
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['0', '1']
plt.title('Confusion Matrix Of Logistic Regression')
plt.ylabel('Actual(true) values')
plt.xlabel('Predicted values')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45) 
plt.yticks(tick_marks, classNames)
s = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2): 
        plt.text(j,i, str(s[i][j])+"="+str(cm[i][j]))
plt.show()

# %%
 pd.crosstab(y_test, lr_pred, margins=False)
# Out:
# col_0     0   1
# Outcome
# 0        86  11
# 1        24  33

# %%
pd.crosstab(y_test, lr_pred, margins=True)
# Out:
# col_0      0   1  All
# Outcome
# 0         86  11   97
# 1         24  33   57
# All      110  44  154

# %%
pd.crosstab(y_test, lr_pred, rownames=['Actual values'], colnames=['Predicted values'], margins= True)
# Out:
# Predicted values    0   1  All
# Actual values
# 0                  86  11   97
# 1                  24  33   57
# All               110  44  154

# %%
TP,FP
# Out:
# (33, 11)

# %% [markdown]
# ### Presicion Positive Predictive Value

# %%
Precision=TP/(TP+FP)
Precision
# Out:
# 0.75

# %%
33/(33+11)
# Out:
# 0.75

# %%
precision_Score = TP / float(TP+FP)*100
print('Precision score : {0:0.4f}'.format(precision_Score))
# Out:
# Precision score : 75.0000

# %%
from sklearn.metrics import precision_score
print("precision Score is:", precision_score(y_test,lr_pred)*100)
print("Mircro Average precision Score is:", precision_score(y_test,lr_pred,average='micro')*100)
print("Marcro Average precision Score is:", precision_score(y_test,lr_pred,average='macro')*100)
print("Weighted Average precision Score is: ", precision_score(y_test,lr_pred,average='weighted')*100)
print("precision Score on Non weighted score is:", precision_score (y_test,lr_pred,average=None)*100)
# Out:
# precision Score is: 75.0
# Mircro Average precision Score is: 77.27272727272727
# Marcro Average precision Score is: 76.5909090909091
# Weighted Average precision Score is:  77.00413223140497
# precision Score on Non weighted score is: [78.18181818 75.        ]

# %%
 print('Classification Report of Logistic Regression: \n',classification_report(y_test,lr_pred,digits=4))
# Out:
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0     0.7818    0.8866    0.8309        97
#            1     0.7500    0.5789    0.6535        57
#
#     accuracy                         0.7727       154
#    macro avg     0.7659    0.7328    0.7422       154
# weighted avg     0.7700    0.7727    0.7652       154

# %%
recall_score= TP/float(TP+FN)*100
print('recall score', recall_score)
# Out:
# recall score 57.89473684210527

# %%
TP,FN
# Out:
# (33, 24)

# %%
33/(33+24)
# Out:
# 0.5789473684210527

# %%
from sklearn.metrics import recall_score
print ('recall or (sensitivity score: ', recall_score(y_test, lr_pred)*100)
# Out:
# recall or (sensitivity score:  57.89473684210527

# %%
print("Mircro Average Recall Score is:", recall_score (y_test, lr_pred, average='micro')*100)
print("Marcro Average Recall Score is:", recall_score (y_test, lr_pred, average='macro')*100)
print("Weighted Average Recall Score is:", recall_score (y_test, lr_pred, average='weighted')*100) 
print("Recall Score on Non weighted score is:", recall_score (y_test, lr_pred, average=None)*100)
# Out:
# Mircro Average Recall Score is: 77.27272727272727
# Marcro Average Recall Score is: 73.27726532826912
# Weighted Average Recall Score is: 77.27272727272727
# Recall Score on Non weighted score is: [88.65979381 57.89473684]

# %%
print('Classification Report of Logistic Regression: \n',classification_report (y_test, lr_pred, digits=4))
# Out:
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0     0.7818    0.8866    0.8309        97
#            1     0.7500    0.5789    0.6535        57
#
#     accuracy                         0.7727       154
#    macro avg     0.7659    0.7328    0.7422       154
# weighted avg     0.7700    0.7727    0.7652       154

# %%
FPR=FP/float(FP+TN)*100
print('False positive rate: {0:0.4f}'.format(FPR))
# Out:
# False positive rate: 11.3402

# %%
FP,TN
# Out:
# (11, 86)

# %%
11/(11+86)
# Out:
# 0.1134020618556701

# %%
specificity=TN/(TN+FP)*100
print('Specificity {0:0.4f}'.format(specificity))
# Out:
# Specificity 88.6598

# %%
from sklearn.metrics import f1_score
print('F1 score of macro :',f1_score(y_test,lr_pred)*100)
# Out:
# F1 score of macro : 65.34653465346535

# %%
print("Mircro Average F1 Score is:", f1_score(y_test, lr_pred, average="micro")*100)
print("Marcro Average F1 Score is:", f1_score (y_test, lr_pred, average="macro")*100)
print("Weighted Average F1 Score is:", f1_score (y_test, lr_pred, average="weighted")*100)
print("F1 Score on Non weighted score is:", f1_score (y_test, lr_pred, average=None)*100)
# Out:
# Mircro Average F1 Score is: 77.27272727272727
# Marcro Average F1 Score is: 74.21916104653944
# Weighted Average F1 Score is: 76.52373933045479
# F1 Score on Non weighted score is: [83.09178744 65.34653465]

# %% [markdown]
# # Classifictaion Report

# %% [markdown]
# ### 1. Logistic Regression

# %%
from sklearn.metrics import classification_report
print('classification report of logistic regression:\n',classification_report(y_test,lr_pred,digits=4))
# Out:
# classification report of logistic regression:
#                precision    recall  f1-score   support
#
#            0     0.7818    0.8866    0.8309        97
#            1     0.7500    0.5789    0.6535        57
#
#     accuracy                         0.7727       154
#    macro avg     0.7659    0.7328    0.7422       154
# weighted avg     0.7700    0.7727    0.7652       154

# %%
auc=roc_auc_score (y_test, lr_pred)
print("ROC AUC SCORE of Logistic Regression is", auc)
# Out:
# ROC AUC SCORE of Logistic Regression is 0.7327726532826913

# %%
fpr, tpr, thresholds = roc_curve(y_test, lr_pred)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--', label='ROC curve (area %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve of Logistic Regression')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 2. KNN

# %%
sns.heatmap(confusion_matrix(y_test,pred_knn),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, pred_knn)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))

print('Accuracy Rate: {}'.format(np.divide(np.sum( [cm[0,0], cm[1,1]]), np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide (np.sum([cm[0,1], cm[1,0]]), np.sum(cm))*100))
# Out:
# TN - True Negative 82
# FP - False Positive 15
# FN - False Negative 24
# TP - True Positive 33
# Accuracy Rate: 74.67532467532467
# Misclassification Rate: 25.324675324675322

# %%
74.67532467532467+25.324675324675322
# Out:
# 100.0

# %%
from sklearn.metrics import classification_report
print('classification report of KNN:\n',classification_report(y_test,pred_knn,digits=4))
# Out:
# classification report of KNN:
#                precision    recall  f1-score   support
#
#            0     0.7736    0.8454    0.8079        97
#            1     0.6875    0.5789    0.6286        57
#
#     accuracy                         0.7468       154
#    macro avg     0.7305    0.7122    0.7182       154
# weighted avg     0.7417    0.7468    0.7415       154

# %%
auc = roc_auc_score(y_test,pred_knn)
print("ROC AUC SCORE of KNN is",auc)
# Out:
# ROC AUC SCORE of KNN is 0.7121540965816603

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_knn)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle= '--', label='ROC curve (area %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve of KNN')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 3. NAIVE BAYES

# %%
sns.heatmap(confusion_matrix(y_test,pred_nb),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, pred_nb)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))

print('Accuracy Rate of Naive Bayes: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]), np.sum(cm))*100))
print('Misclassification Rate of Naive Bayes: {}'.format(np.divide (np.sum ([cm[0,1], cm[1,0]]), np.sum(cm))*100))
# Out:
# TN - True Negative 78
# FP - False Positive 19
# FN - False Negative 21
# TP - True Positive 36
# Accuracy Rate of Naive Bayes: 74.02597402597402
# Misclassification Rate of Naive Bayes: 25.97402597402597

# %%
74.02597402597402+25.97402597402597
# Out:
# 100.0

# %%
print('Classification Report of Naive Bayes:\n',classification_report(y_test,pred_nb,digits=4))
# Out:
# Classification Report of Naive Bayes:
#                precision    recall  f1-score   support
#
#            0     0.7879    0.8041    0.7959        97
#            1     0.6545    0.6316    0.6429        57
#
#     accuracy                         0.7403       154
#    macro avg     0.7212    0.7179    0.7194       154
# weighted avg     0.7385    0.7403    0.7393       154

# %%
auc = roc_auc_score(y_test,pred_nb)
print("ROC AUC SCORE of Naive Bayes is",auc)
# Out:
# ROC AUC SCORE of Naive Bayes is 0.7178513293543136

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_nb)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle= '--', label='ROC curve (area %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve of Naive Bayes')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 4. DECISION TREE

# %%
sns.heatmap(confusion_matrix(y_test,pred_dt),annot=True,fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, pred_dt)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))

print('Accuracy Rate of Naive Bayes: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]), np.sum(cm))*100))
print('Misclassification Rate of Naive Bayes: {}'.format(np.divide (np.sum ([cm[0,1], cm[1,0]]), np.sum(cm))*100))
# Out:
# TN - True Negative 83
# FP - False Positive 14
# FN - False Negative 15
# TP - True Positive 42
# Accuracy Rate of Naive Bayes: 81.16883116883116
# Misclassification Rate of Naive Bayes: 18.83116883116883

# %%
print('Classification Report of DT:\n',classification_report(y_test,pred_dt,digits=4))
# Out:
# Classification Report of DT:
#                precision    recall  f1-score   support
#
#            0     0.8469    0.8557    0.8513        97
#            1     0.7500    0.7368    0.7434        57
#
#     accuracy                         0.8117       154
#    macro avg     0.7985    0.7963    0.7973       154
# weighted avg     0.8111    0.8117    0.8113       154

# %%
from sklearn.metrics import roc_auc_score
auc = round(roc_auc_score(y_test,pred_dt)*100,2)
print('roc_auc_score of DT:',auc)
# Out:
# roc_auc_score of DT: 79.63

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_dt)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle= '--', label='ROC curve (area %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) DT')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 5. SVC

# %%
sns.heatmap(confusion_matrix(y_test, pred_svc),annot= True, fmt="d" )
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm= confusion_matrix(y_test, pred_svc)
print('TN-True negative{}'.format (cm[0,0]))
print('FP-False positive{}'.format (cm[0,1]))
print('TP-True negative{}'.format (cm[1,1]))
print('FN-False positive{}'.format (cm[1,0]))
print('Accuracy rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Miscalssification rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))
# Out:
# TN-True negative91
# FP-False positive6
# TP-True negative37
# FN-False positive20
# Accuracy rate: 0.8311688311688312
# Miscalssification rate: 0.16883116883116883

# %%
print('classification report of SVM: \n', classification_report(y_test, pred_svc, digits=4))
# Out:
# classification report of SVM:
#                precision    recall  f1-score   support
#
#            0     0.8198    0.9381    0.8750        97
#            1     0.8605    0.6491    0.7400        57
#
#     accuracy                         0.8312       154
#    macro avg     0.8401    0.7936    0.8075       154
# weighted avg     0.8349    0.8312    0.8250       154

# %%
from sklearn.metrics import roc_auc_score
auc=round(roc_auc_score(y_test,pred_svc)*100,2)
print('roc_auc_score of SVC:', auc)
# Out:
# roc_auc_score of SVC: 79.36

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_svc)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle= '--', label='ROC curve (area %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve of SVC')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 6. RANDOM FOREST

# %%
sns.heatmap(confusion_matrix(y_test, pred_rf),annot= True, fmt="d" )
# Out:
# <Axes: >

# %%
cm= confusion_matrix(y_test, pred_rf)
print('TN-True negative{}'.format (cm[0,0]))
print('FP-False positive{}'.format (cm[0,1]))
print('TP-True negative{}'.format (cm[1,1]))
print('FN-False positive{}'.format (cm[1,0]))
print('Accuracy rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Miscalssification rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))
# Out:
# TN-True negative83
# FP-False positive14
# TP-True negative37
# FN-False positive20
# Accuracy rate: 0.7792207792207793
# Miscalssification rate: 0.22077922077922077

# %%
print('classification report of Random Forest: \n', classification_report(y_test, pred_rf, digits=4))
# Out:
# classification report of Random Forest:
#                precision    recall  f1-score   support
#
#            0     0.8058    0.8557    0.8300        97
#            1     0.7255    0.6491    0.6852        57
#
#     accuracy                         0.7792       154
#    macro avg     0.7657    0.7524    0.7576       154
# weighted avg     0.7761    0.7792    0.7764       154

# %%
from sklearn.metrics import roc_auc_score
auc=round(roc_auc_score(y_test,pred_rf)*100,2)
print('roc_auc_score of RF:', auc)
# Out:
# roc_auc_score of RF: 75.24

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_rf)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle= '--', label='ROC curve (area %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve of RANDOM FOREST')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # END
